# %% [markdown]
# # Data Integration
# ## Data Compressive Strength

# %%
import pandas as pd
import numpy as np

# %%
#membaca data
variabel = pd.read_csv ('variabel.csv')
indeks =pd.read_csv('indeks.csv')
variabel
# Out:
#      Case  Cement  Blast  Fly Ash  Water
# 0       1   540.0    0.0        0  162.0
# 1       2   540.0    0.0        0  162.0
# 2       3   332.5  142.5        0  228.0
# 3       4   332.5  142.5        0  228.0
# 4       5   198.6  132.4        0  192.0
# 5       6   266.0  114.0        0  228.0
# 6       7   380.0   95.0        0  228.0
# 7       8   380.0   95.0        0  228.0
# 8       9   266.0  114.0        0  228.0
# 9      10   475.0    0.0        0  228.0
# 10     11   198.6  132.4        0  192.0
# 11     12   198.6  132.4        0  192.0
# 12     13   427.5   47.5        0  228.0
# 13     14   190.0  190.0        0  228.0
# 14     15   304.0   76.0        0  228.0
# 15     16   380.0    0.0        0  228.0
# 16     17   139.6  209.4        0  192.0
# 17     18   342.0   38.0        0  228.0
# 18     19   380.0   95.0        0  228.0
# 19     20   475.0    0.0        0  228.0
# 20     21   427.5   47.5        0  228.0
# 21     22   139.6  209.4        0  192.0
# ...

# %%
#menggabungkan data
data = pd.merge(variabel, indeks, on=['Case'])
data
# Out:
#      Case  Cement  Blast  Fly Ash  Water    SP  Coarse Agg  Fine Agg  Age
# 0       1   540.0    0.0        0  162.0   2.5      1040.0     676.0   28
# 1       2   540.0    0.0        0  162.0   2.5      1055.0     676.0   28
# 2       3   332.5  142.5        0  228.0   0.0       932.0     594.0  270
# 3       4   332.5  142.5        0  228.0   0.0       932.0     594.0  365
# 4       5   198.6  132.4        0  192.0   0.0       978.4     825.5  360
# 5       6   266.0  114.0        0  228.0   0.0       932.0     670.0   90
# 6       7   380.0   95.0        0  228.0   0.0       932.0     594.0  365
# 7       8   380.0   95.0        0  228.0   0.0       932.0     594.0   28
# 8       9   266.0  114.0        0  228.0   0.0       932.0     670.0   28
# 9      10   475.0    0.0        0  228.0   0.0       932.0     594.0   28
# 10     11   198.6  132.4        0  192.0   0.0       978.4     825.5   90
# 11     12   198.6  132.4        0  192.0   0.0       978.4     825.5   28
# ...

# %%
#menghapus kolom
data1= data.drop(['Fly Ash'], axis=1)
data1
# Out:
#      Case  Cement  Blast  Water    SP  Coarse Agg  Fine Agg  Age
# 0       1   540.0    0.0  162.0   2.5      1040.0     676.0   28
# 1       2   540.0    0.0  162.0   2.5      1055.0     676.0   28
# 2       3   332.5  142.5  228.0   0.0       932.0     594.0  270
# 3       4   332.5  142.5  228.0   0.0       932.0     594.0  365
# 4       5   198.6  132.4  192.0   0.0       978.4     825.5  360
# 5       6   266.0  114.0  228.0   0.0       932.0     670.0   90
# 6       7   380.0   95.0  228.0   0.0       932.0     594.0  365
# 7       8   380.0   95.0  228.0   0.0       932.0     594.0   28
# 8       9   266.0  114.0  228.0   0.0       932.0     670.0   28
# 9      10   475.0    0.0  228.0   0.0       932.0     594.0   28
# 10     11   198.6  132.4  192.0   0.0       978.4     825.5   90
# 11     12   198.6  132.4  192.0   0.0       978.4     825.5   28
# 12     13   427.5   47.5  228.0   0.0       932.0     594.0  270
# ...

# %%
#memunculkan 5 data teratas
data1.head()
# Out:
#    Case  Cement  Blast  Water   SP  Coarse Agg  Fine Agg  Age
# 0     1   540.0    0.0  162.0  2.5      1040.0     676.0   28
# 1     2   540.0    0.0  162.0  2.5      1055.0     676.0   28
# 2     3   332.5  142.5  228.0  0.0       932.0     594.0  270
# 3     4   332.5  142.5  228.0  0.0       932.0     594.0  365
# 4     5   198.6  132.4  192.0  0.0       978.4     825.5  360

# %%
#memunculkan 5 data terakhir
data1.tail()
# Out:
#      Case  Cement  Blast  Water    SP  Coarse Agg  Fine Agg  Age
# 145   146   469.0  117.2  137.8  32.2       852.1     840.5   56
# 146   147   425.0  106.3  153.5  16.5       852.1     887.1   56
# 147   148   388.6   97.1  157.9  12.1       852.1     925.7   56
# 148   149   531.3    0.0  141.8  28.2       852.1     893.7   56
# 149   150   425.0  106.3  153.5  16.5       852.1     887.1   56
