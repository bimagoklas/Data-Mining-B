# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('data tugas.xlsx')

# %%
data.head(10)
# Out:
#    age     workclass  fnlwgt      education  education-num  \
# 0   45     Local-gov  164427      Bachelors             13
# 1   38       Private   91039      Bachelors             13
# 2   40       Private  347934        HS-grad              9
# 3   46   Federal-gov  371373        HS-grad              9
# 4   35       Private   32220     Assoc-acdm             12
# 5   34       Private  187251        HS-grad              9
# 6   33       Private  178107      Bachelors             13
# 7   41       Private  343121        HS-grad              9
# 8   20       Private  262749   Some-college             10
# 9   23       Private  403107        5th-6th              3
#
#         marital-status          occupation    relationship    race      sex  \
# 0             Divorced      Prof-specialty       Unmarried   White   Female
# 1   Married-civ-spouse               Sales         Husband   White     Male
# 2        Never-married       Other-service   Not-in-family   White   Female
# 3             Divorced        Adm-clerical   Not-in-family   White     Male
# 4        Never-married     Exec-managerial   Not-in-family   White   Female
# 5             Divorced      Prof-specialty       Unmarried   White   Female
# 6        Never-married        Craft-repair       Own-child   White     Male
# 7             Divorced        Adm-clerical       Unmarried   White   Female
# 8        Never-married   Machine-op-inspct       Own-child   White     Male
# 9        Never-married       Other-service       Own-child   White     Male
#
#    capital-gain  capital-loss  hours-per-week  native-country    type
# 0             0             0              40   United-States   <=50K
# 1         15024             0              60   United-States    >50K
# 2             0             0              35   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              60   United-States   <=50K
# 5             0             0              25   United-States   <=50K
# 6             0             0              20   United-States   <=50K
# 7             0             0              36   United-States   <=50K
# 8             0             0              40   United-States   <=50K
# 9             0             0              40     El-Salvador   <=50K

# %% [markdown]
# ## Membaca data kosong sebagai missing value

# %%
data = data.replace(' ?',np.nan)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 15 columns):
# age               300 non-null int64
# workclass         281 non-null object
# fnlwgt            300 non-null int64
# education         300 non-null object
# education-num     300 non-null int64
# marital-status    300 non-null object
# occupation        281 non-null object
# relationship      300 non-null object
# race              300 non-null object
# sex               300 non-null object
# capital-gain      300 non-null int64
# capital-loss      300 non-null int64
# hours-per-week    300 non-null int64
# native-country    295 non-null object
# type              300 non-null object
# dtypes: int64(6), object(9)
# memory usage: 35.2+ KB

# %% [markdown]
# ## Memisahkan kolom2

# %%
Y = ['type']
X_int_1 = ['age', 'education-num']
X_int_2 = ['hours-per-week', 'capital-gain','capital-loss','fnlwgt']
X_cat = ['workclass', 'education', 'marital-status', 'occupation', 'relationship','race','sex','native-country']

# %%
data_Y = data[Y]
data_int = data[X_int_1].astype(int)
data_float = data[X_int_2].astype(float)
data_cat = data[X_cat]

# %% [markdown]
# ## Melihat jumlah tipe

# %%
#show all distinct value of class
print(data_Y['type'].unique())
# Out:
# [' <=50K' ' >50K']

# %% [markdown]
# ### mengganti missing data

# %%
data.isnull().sum()
# Out:
# age                0
# workclass         19
# fnlwgt             0
# education          0
# education-num      0
# marital-status     0
# occupation        19
# relationship       0
# race               0
# sex                0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     5
# type               0
# dtype: int64

# %%
## find missing data for each data type and fill it with mean and mode
data_cat_array = []
for class_name in data_Y['type'].unique():
    data_cat_1 = data_cat[data_Y['type']==class_name]
    data_cat_clean_1 = data_cat_1.where(pd.notnull(data_cat_1), data_cat_1.mode(), axis='columns')
    data_cat_array.append(data_cat_clean_1)

# %%
data_cat_clean = pd.concat(data_cat_array)

# %%
data_cleaned_sebelum = pd.concat([data_int, data_float, data_cat_clean, data_Y], axis=1)

# %%
data_cleaned_sebelum.isnull().any()
# Out:
# age               False
# education-num     False
# hours-per-week    False
# capital-gain      False
# capital-loss      False
# fnlwgt            False
# workclass         False
# education         False
# marital-status    False
# occupation        False
# relationship      False
# race              False
# sex               False
# native-country    False
# type              False
# dtype: bool

# %% [markdown]
# ## Standardisasi

# %%
from sklearn.preprocessing import StandardScaler

# %%
data_float['fnlwgt'] = StandardScaler().fit(data_float[['fnlwgt']]).transform(data_float[['fnlwgt']])
data_int['education-num'] = StandardScaler().fit(data_int[['education-num']]).transform(data_int[['education-num']])
data_float['capital-gain'] = StandardScaler().fit(data_float[['capital-gain']]).transform(data_float[['capital-gain']])
data_float['capital-loss'] = StandardScaler().fit(data_float[['capital-loss']]).transform(data_float[['capital-loss']])
data_float['hours-per-week'] = StandardScaler().fit(data_float[['hours-per-week']]).transform(data_float[['hours-per-week']])
# Out:
# /Users/macbook/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
data_cleaned = pd.concat([data_int, data_float, data_cat_clean, data_Y], axis=1)
data_cleaned.head(10)
# Out:
#    age  education-num  hours-per-week  capital-gain  capital-loss    fnlwgt  \
# 0   45       1.177309        0.023696     -0.152801      -0.19734 -0.246596
# 1   38       1.177309        1.639366      2.212352      -0.19734 -0.972423
# 2   40      -0.465448       -0.380221     -0.152801      -0.19734  1.568336
# 3   46      -0.465448        0.023696     -0.152801      -0.19734  1.800153
# 4   35       0.766620        1.639366     -0.152801      -0.19734 -1.554158
# 5   34      -0.465448       -1.188056     -0.152801      -0.19734 -0.020861
# 6   33       1.177309       -1.591973     -0.152801      -0.19734 -0.111298
# 7   41      -0.465448       -0.299437     -0.152801      -0.19734  1.520734
# 8   20      -0.054759        0.023696     -0.152801      -0.19734  0.725834
# 9   23      -2.929583        0.023696     -0.152801      -0.19734  2.114011
#
#       workclass      education       marital-status          occupation  \
# 0     Local-gov      Bachelors             Divorced      Prof-specialty
# 1       Private      Bachelors   Married-civ-spouse               Sales
# 2       Private        HS-grad        Never-married       Other-service
# 3   Federal-gov        HS-grad             Divorced        Adm-clerical
# 4       Private     Assoc-acdm        Never-married     Exec-managerial
# 5       Private        HS-grad             Divorced      Prof-specialty
# 6       Private      Bachelors        Never-married        Craft-repair
# 7       Private        HS-grad             Divorced        Adm-clerical
# 8       Private   Some-college        Never-married   Machine-op-inspct
# 9       Private        5th-6th        Never-married       Other-service
#
#      relationship    race      sex  native-country    type
# 0       Unmarried   White   Female   United-States   <=50K
# 1         Husband   White     Male   United-States    >50K
# 2   Not-in-family   White   Female   United-States   <=50K
# 3   Not-in-family   White     Male   United-States   <=50K
# 4   Not-in-family   White   Female   United-States   <=50K
# 5       Unmarried   White   Female   United-States   <=50K
# 6       Own-child   White     Male   United-States   <=50K
# 7       Unmarried   White   Female   United-States   <=50K
# 8       Own-child   White     Male   United-States   <=50K
# 9       Own-child   White     Male     El-Salvador   <=50K

# %% [markdown]
# ### deteksi outlier

# %%
### for detect outlier
data_num_w_type = pd.concat([data_int, data_float, data_Y], axis=1)

# %%
data_num_w_type.head()
# Out:
#    age  education-num  hours-per-week  capital-gain  capital-loss    fnlwgt  \
# 0   45       1.177309        0.023696     -0.152801      -0.19734 -0.246596
# 1   38       1.177309        1.639366      2.212352      -0.19734 -0.972423
# 2   40      -0.465448       -0.380221     -0.152801      -0.19734  1.568336
# 3   46      -0.465448        0.023696     -0.152801      -0.19734  1.800153
# 4   35       0.766620        1.639366     -0.152801      -0.19734 -1.554158
#
#      type
# 0   <=50K
# 1    >50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
plt.rcParams['figure.figsize'] = (15.0, 10.0)

# %%
# Univariate Density Plots
data_num_w_type.plot(kind= 'density ' , subplots=True, layout=(3,3), sharex=False)
plt.show()

# %%
data_num_w_type.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False)
plt.show()

# %%
colors_palette = {" >50K": "red",  " <=50K": "blue"}
colors = [colors_palette[c] for c in data_num_w_type['type']]

# %%
## red : >50K
## blue: <=50K
from pandas.plotting import scatter_matrix
scatter_matrix(data_num_w_type, color=colors, diagonal='kde')
plt.show()

# %%
data_cleaned = pd.concat([data_num_w_type, data_cat_clean], axis=1)

# %%
# rearrange columns position to default
data_cleaned = data_cleaned[data.columns]
data_cleaned.head()
# Out:
#    age     workclass    fnlwgt    education  education-num  \
# 0   45     Local-gov -0.246596    Bachelors       1.177309
# 1   38       Private -0.972423    Bachelors       1.177309
# 2   40       Private  1.568336      HS-grad      -0.465448
# 3   46   Federal-gov  1.800153      HS-grad      -0.465448
# 4   35       Private -1.554158   Assoc-acdm       0.766620
#
#         marital-status        occupation    relationship    race      sex  \
# 0             Divorced    Prof-specialty       Unmarried   White   Female
# 1   Married-civ-spouse             Sales         Husband   White     Male
# 2        Never-married     Other-service   Not-in-family   White   Female
# 3             Divorced      Adm-clerical   Not-in-family   White     Male
# 4        Never-married   Exec-managerial   Not-in-family   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country    type
# 0     -0.152801      -0.19734        0.023696   United-States   <=50K
# 1      2.212352      -0.19734        1.639366   United-States    >50K
# 2     -0.152801      -0.19734       -0.380221   United-States   <=50K
# 3     -0.152801      -0.19734        0.023696   United-States   <=50K
# 4     -0.152801      -0.19734        1.639366   United-States   <=50K

# %%
data_cleaned.to_csv('Bima Putra Goklas_06211640000124.csv', index=0)
